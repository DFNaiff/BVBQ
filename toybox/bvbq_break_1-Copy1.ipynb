# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

import collections
import functools
import abc
import random

import numpy as np
import jax
import jax.numpy as jnp
import jax.experimental.optimizers
import scipy.stats
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import sobol_seq
import dict_minimize
from pytictoc import TicToc

import bvbq

# import bvbq.gp
# import bvbq.bvi
# import bvbq.distributions

# %%
random.random()
# Out:
# 0.8553651661648254

# %%
key1 = jax.random.PRNGKey(250)
key2,_ = jax.random.split(key1)
# mixmeans_test = 4*jax.random.normal(key1,shape=(12,1))
mixmeans_test = jnp.ones((12,1))
mixmeans_test = jnp.array([[  1.8033],
                           [ -1.4296],
                           [ -1.9691],
                           [  1.2147],
                           [ -6.9166],
                           [-11.5672],
                           [ -1.5860],
                           [ -4.3302],
                           [  8.7410],
                           [ -1.3793],
                           [ -4.8774],
                           [  2.3949]])
mixvars_test = jnp.ones((12,1))
mixweights_test = jnp.ones(12)/12
# mixmeans_test = jnp.array([[3.0],[-3.0]])
# mixvars_test = jnp.ones((2,1))
# mixweights_test = jnp.ones(2)/2
# bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
#                     samples,mixmeans,mixvars,mixweights)

# %%
def logprob_mixgaussians(x):
    return bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
                        x,mixmeans_test,mixvars_test,mixweights_test).reshape(-1,1)
def logprob_t(x,nu):
    normalizer = jax.scipy.special.gammaln((nu+1)/2) \
                 -jax.scipy.special.gammaln(nu/2) \
                 -0.5*jnp.log(jnp.pi*nu)
    main_term = -(nu+1)/2*jnp.log(1+x**2/nu)
    return main_term + normalizer

xdata = jnp.linspace(-20,20,51).reshape(-1,1)
# ydata = logprob_t(xdata,2.5)
ydata = logprob_mixgaussians(xdata)
logprobgp = bvbq.gp.SimpleGP(1,kind='sqe',noise=0,zeromax=True)
logprobgp.mean = -10.0
logprobgp.fix_mean()
logprobgp.fix_noise()
logprobgp.set_data(xdata,ydata,empirical_params=False)
logprobgp.optimize_params()
# Out:
# OrderedDict([('raw_theta', DeviceArray(0.5413248, dtype=float32)),
#              ('raw_lengthscale', DeviceArray(0.5413248, dtype=float32)),
#              ('raw_noise', DeviceArray(-inf, dtype=float32))])

# %%
xplot = np.linspace(-20,20,201).reshape(-1,1)
yplot1 = logprob_mixgaussians(xplot)
# yplot1 = logprob_t(xplot,2.5)
yplot2 = logprobgp.predict(xplot,return_cov=False)
plt.plot(xplot,jnp.exp(yplot1),'b')
plt.plot(xplot,jnp.exp(yplot2),'r')
samples1 = bvbq.distributions.MixtureDiagonalNormalDistribution.sample_(100000,
                                                             mixmeans_test,
                                                             mixvars_test,
                                                             mixweights_test,
                                                             key1,key2)
plt.hist(samples1.flatten(),density=True,bins=100);

# %%
def mcbq_dmvn_elbo(logprobgp,mean,var,nsamples):
    term1 = 0.5*jnp.sum(jnp.log(2*jnp.pi*jnp.e*var))
    term2 = bvbq.bq.separable_dmvn_bq(logprobgp,mean,var,return_var=False)
    return term1 + term2
#     term1 = distrib.monte_carlo_entropy(nsamples)
#     term2 = bq.monte_carlo_bayesian_quadrature(logprobgp,distrib,nsamples)
#     return term1 + term2

def objective_function_elbo(params):
    mean,rawvar = params['mean'],params['rawvar']
    var = jax.nn.softplus(rawvar)
    res = -mcbq_dmvn_elbo(logprobgp,mean,var,1000)
    return res

# %%
params = {'mean':jnp.zeros(1)-1.0,'rawvar':jnp.zeros(1)}
jax.value_and_grad(objective_function_elbo)(params)
maxiter = 100
alpha = 1e-1
optwrapper = bvbq.optwrapper.JaxOptWrapper("adam",alpha)
func_and_grad_elbo = jax.value_and_grad(objective_function_elbo)
optwrapper.init(params,func_and_grad_elbo)
for k in range(maxiter):
    value,grads = optwrapper.step()
    params = optwrapper.params
#     print(value,params['mean'],jax.nn.softplus(params['rawvar']))
mean,rawvar = params['mean'],params['rawvar']
var = jax.nn.softplus(rawvar)
distrib = bvbq.distributions.DiagonalNormalDistribution(mean,var)

# %%
xplot = np.linspace(-20,20,201).reshape(-1,1)
# yplot1 = logprob_t(xplot,2.5)
yplot1 = logprob_mixgaussians(xplot)
yplot2 = logprobgp.predict(xplot,return_cov=False)
yplot3 = distrib.logprob(xplot).reshape(-1,1)
plt.plot(xplot,jnp.exp(yplot1),'b')
plt.plot(xplot,jnp.exp(yplot2),'r')
plt.plot(xplot,jnp.exp(yplot3),'g')
samples1 = bvbq.distributions.MixtureDiagonalNormalDistribution.sample_(10000,
                                                             mixmeans_test,
                                                             mixvars_test,
                                                             mixweights_test,
                                                             key1,key2)
samples3 = distrib.sample(10000)
plt.hist(samples1.flatten(),density=True,bins=100,alpha=0.5,color='blue');
plt.hist(samples3.flatten(),density=True,bins=100,alpha=0.5,color='green');

# %%
def mcbq_dmvn_relbo(logprobgp,mean,var,mixmeans,mixvars,mixweights,
                    zsamples,logdelta,reg):
    samples = jnp.sqrt(var)*zsamples + mean
    term1 = bvbq.bq.separable_dmvn_bq(logprobgp,mean,var,return_var=False) #Variance
#     term2 = bvbq.utils.lb_mvn_mixmvn_cross_entropy(mean,var,mixmeans,mixvars,mixweights,logdelta)
    term2_ = bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
                    samples,mixmeans,mixvars,mixweights)
    term2_ = bvbq.utils.logbound(term2_,logdelta)
    term2 = -term2_.mean()
    term3 = 0.5*jnp.sum(jnp.log(2*jnp.pi*jnp.e*var)) #Entropy
    return term1 + term2 + reg*term3

def mcbq_mixdmvn_gradboost_delbodw(weight,logprobgp,mean,var,
                                   mixmeans,mixvars,mixweights,
                                   key,nsamples=100):
    mixmeans_up = jnp.vstack([mixmeans,mean])
    mixvars_up = jnp.vstack([mixvars,var])
    mixweights_up = jnp.append((1-weight)*mixweights,weight)

    subkeya,key = jax.random.split(key)
    subkeyb,key = jax.random.split(key)
    subkeyc,key = jax.random.split(key)

    nmixtures,ndim = mixmeans.shape
    catinds = jax.random.choice(subkeya,nmixtures,shape=(nsamples,),p=mixweights)
    zprevious = jax.random.normal(subkeyb,shape=(nsamples,ndim))
    zproposal = jax.random.normal(subkeyc,shape=(nsamples,ndim))
    samplesprevious = bvbq.utils.mixdmvn_samples_from_zsamples_catinds(mixmeans,mixvars,zprevious,catinds)
    samplesproposal = bvbq.utils.dmvn_samples_from_zsamples(mean,var,zproposal)

    term1 = bvbq.bq.separable_dmvn_bq(logprobgp,mean,var,return_var=False) 
    term2 = -bvbq.bq.separable_mixdmvn_bq(logprobgp,mixmeans,
                                          mixvars,mixweights,
                                          return_var=False)
    term3 = -bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
                samplesproposal,mixmeans_up,mixvars_up,mixweights_up).mean()
    term4 = bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
                samplesprevious,mixmeans_up,mixvars_up,mixweights_up).mean()
    return term1 + term2 + term3 + term4

# @jax.jit
def mcbq_mixdmvn_gradboost_delbodw_term34(weight,term1,term2,mean,var,
                                          mixmeans,mixvars,mixweights,
                                          catinds,zprevious,zproposal):
    mixmeans_up = jnp.vstack([mixmeans,mean])
    mixvars_up = jnp.vstack([mixvars,var])
    mixweights_up = jnp.append((1-weight)*mixweights,weight)

    samplesprevious = bvbq.utils.mixdmvn_samples_from_zsamples_catinds(mixmeans,mixvars,zprevious,catinds)
    samplesproposal = bvbq.utils.dmvn_samples_from_zsamples(mean,var,zproposal)

    term3 = -bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
                samplesproposal,mixmeans_up,mixvars_up,mixweights_up).mean()
    term4 = bvbq.distributions.MixtureDiagonalNormalDistribution.logprob_(
                samplesprevious,mixmeans_up,mixvars_up,mixweights_up).mean()
    return term1 + term2 + term3 + term4

def make_gradboost_samples(key,nsamples,mixweights,nmixtures,ndim):
    subkeya,key = jax.random.split(key)
    subkeyb,key = jax.random.split(key)
    subkeyc,key = jax.random.split(key)

    nmixtures,ndim = mixmeans.shape
    catinds = jax.random.choice(subkeya,nmixtures,shape=(nsamples,),p=mixweights)
    zprevious = jax.random.normal(subkeyb,shape=(nsamples,ndim))
    zproposal = jax.random.normal(subkeyc,shape=(nsamples,ndim))
    return catinds,zprevious,zproposal

# %%
def objective_function_relbo(params,mixmeans,mixvars,mixweights,
                             logdelta,reg,nsamples,key):
    mean,rawvar = params['mean'],params['rawvar']
    zsamples = jax.random.normal(key,shape=(nsamples,mean.shape[0]))
    var = jax.nn.softplus(rawvar)
    res = -bvbq.bvbq_functions.mcbq_dmvn_relbo(logprobgp,mean,var,mixmeans,mixvars,mixweights,zsamples,logdelta,reg)
    return res

func_and_grad_relbo = jax.value_and_grad(objective_function_relbo,argnums=0)

# %%
# mean,var = distrib.params
# mixmeans = mean.reshape(1,-1)
# mixvars = var.reshape(1,-1)
dim = 1
mean = jnp.zeros((dim,))
var = (20.0/3)**2*jnp.ones((dim,))
mean,var = distrib.params
mixmeans = jnp.expand_dims(mean,-1)
mixvars = jnp.expand_dims(var,-1)*12
mixweights = jnp.ones(1)

alpha_relbo = 0.1
maxiter_relbo = 100
alpha_boost = 0.1
maxiter_boost = 100
maxiter = 400
optwrapper = bvbq.optwrapper.JaxOptWrapper("adam",alpha_relbo)

key = jax.random.PRNGKey(365)

tictoc = TicToc()
for k in range(maxiter):
    tictoc.tic()
    subkeya,key = jax.random.split(key)
    subkeyb,key = jax.random.split(key)
    subkeyc,key = jax.random.split(key)
    mean_init = bvbq.distributions.MixtureDiagonalNormalDistribution.sample_(
                    1,mixmeans,mixvars,mixweights,subkeya,subkeyb)[0]
    var_init = jnp.array(scipy.stats.halfnorm.rvs(size=(1,)),dtype=jnp.float32)
    rawvar_init = jnp.log(jnp.exp(var_init)-1)
    params = {'mean':mean_init,
              'rawvar':rawvar_init}
    params = collections.OrderedDict(params)
    
    optwrapper.init(params,func_and_grad_relbo)
    reg = random.random()
    for i in range(maxiter_relbo):
        subkeyd,key = jax.random.split(key)
        value,grads = optwrapper.step(mixmeans,mixvars,mixweights,-20,reg,
                                      1000,subkeyd)
    params = optwrapper.params
#     res = dict_minimize.jax_api.minimize(func_and_grad_relbo, params,
#                                          args=(mixmeans,mixvars,mixweights,-20,random.random(),
#                                                1000,subkeyd),
#                                          method='L-BFGS-B',
#                                          tol=1e-6)
    tictoc.toc()
    mean,var = params['mean'],jax.nn.softplus(params['rawvar'])
    weight = 1e-4
    term1 = bvbq.bq.separable_dmvn_bq(logprobgp,mean,var,return_var=False) 
    term2 = -bvbq.bq.separable_mixdmvn_bq(logprobgp,mixmeans,
                                          mixvars,mixweights,
                                          return_var=False)
    nmixtures,ndim = mixmeans.shape
    tictoc.tic()
    nsamples = 100
    for i in range(maxiter_boost):
        subkeye,key = jax.random.split(key)
        catinds,zprevious,zproposal = make_gradboost_samples(subkeye,nsamples,mixweights,nmixtures,ndim)
        gradweight = -mcbq_mixdmvn_gradboost_delbodw_term34(weight,term1,term2,mean,var,
                                                            mixmeans,mixvars,mixweights,
                                                            catinds,zprevious,zproposal)
        dweight = alpha_boost/(k+1)*gradweight
        weight -= dweight
        weight = jnp.clip(weight,1e-4,1-1e-4)
        if abs(gradweight) < 1e-4:
            break
    tictoc.toc()
#     mixdistrib.add_component(mean,var,weight)
    mixweights = jnp.append((1-weight)*mixweights,weight)
    mixmeans = jnp.vstack([mixmeans,mean])
    mixvars = jnp.vstack([mixvars,var])
    print(k,mean,var,weight)
    print('--')
# Out:
# Elapsed time is 3.860047 seconds.
# Elapsed time is 1.957695 seconds.
# 0 [-11.650252] [0.523025] 0.36141512
# --
# Elapsed time is 3.163304 seconds.
# Elapsed time is 1.098759 seconds.
# 1 [-2.1017208] [6.844118] 0.96465546
# --
# Elapsed time is 3.318795 seconds.
# Elapsed time is 1.130336 seconds.
# 2 [2.6523876] [0.27660152] 0.08283778
# --
# Elapsed time is 3.162522 seconds.
# Elapsed time is 1.103293 seconds.
# 3 [1.100503] [8.041198] 0.06734057
# --
# Elapsed time is 3.239716 seconds.
# Elapsed time is 0.593997 seconds.
# 4 [-0.5829338] [7.3400474] 0.0027548722
# --
# Elapsed time is 3.241774 seconds.
# Elapsed time is 1.105618 seconds.
# 5 [-0.87005925] [9.272048] 0.026347354
# --
# Elapsed time is 3.272381 seconds.
# Elapsed time is 1.118016 seconds.
# 6 [0.08073165] [4.9894958] 0.0013914964
# --
# Elapsed time is 3.369550 seconds.
# Elapsed time is 1.102539 seconds.
# 7 [-12.039369] [1.1379865] 0.072043866
# --
# Elapsed time is 3.290134 seconds.
# Elapsed time is 1.113928 seconds.
# 8 [-7.5872474] [0.08665314] 0.019957647
# --
# Elapsed time is 3.313746 seconds.
# Elapsed time is 1.112285 seconds.
# 9 [1.7500024] [0.4013305] 0.05728685
# --
# Elapsed time is 3.292978 seconds.
# Elapsed time is 1.130074 seconds.
# 10 [-4.0580716] [7.6696954] 0.06667519
# --
# Elapsed time is 3.258251 seconds.
# Elapsed time is 1.194232 seconds.
# 11 [-2.2385828] [6.1905727] 0.0008217261
# --
# Elapsed time is 3.326272 seconds.
# Elapsed time is 1.146849 seconds.
# 12 [-1.5243121] [0.02602996] 0.020832293
# --
# Elapsed time is 3.370914 seconds.
# Elapsed time is 1.152340 seconds.
# 13 [-0.29023975] [4.181061] 0.0040697306
# --
# Elapsed time is 3.323055 seconds.
# Elapsed time is 1.162874 seconds.
# 14 [-6.648197] [0.09269632] 0.018616756
# --
# Elapsed time is 3.331416 seconds.
# Elapsed time is 1.174225 seconds.
# 15 [-10.075573] [3.2704554] 0.015785703
# --
# Elapsed time is 3.366100 seconds.
# Elapsed time is 1.190099 seconds.
# 16 [1.4284506] [0.01825724] 0.0064638727
# --
# Elapsed time is 3.392848 seconds.
# Elapsed time is 1.172960 seconds.
# 17 [-6.2580366] [8.189697] 0.0043230397
# --
# Elapsed time is 3.332709 seconds.
# Elapsed time is 1.049359 seconds.
# 18 [-6.194649] [8.620532] 0.009436751
# --
# Elapsed time is 3.287992 seconds.
# Elapsed time is 1.091398 seconds.
# 19 [0.92929393] [2.1419988] 0.014208136
# --
# Elapsed time is 3.321758 seconds.
# Elapsed time is 1.081144 seconds.
# 20 [-1.4234561] [0.5253474] 0.030726502
# --
# Elapsed time is 3.342283 seconds.
# Elapsed time is 1.078639 seconds.
# 21 [-0.4464897] [6.2119546] 0.0066388985
# --
# Elapsed time is 3.316515 seconds.
# Elapsed time is 1.067877 seconds.
# 22 [-0.25280932] [5.46134] 1e-04
# --
# Elapsed time is 3.277747 seconds.
# Elapsed time is 1.063007 seconds.
# 23 [-6.290525] [8.238419] 0.009421683
# --
# Elapsed time is 3.319194 seconds.
# Elapsed time is 1.090583 seconds.
# 24 [-5.4379115] [3.725002] 0.0020680663
# --
# Elapsed time is 3.306359 seconds.
# Elapsed time is 1.089556 seconds.
# 25 [-4.4359274] [7.906363] 0.0037584135
# --
# Elapsed time is 3.334898 seconds.
# Elapsed time is 1.128782 seconds.
# 26 [-0.7373073] [8.266878] 0.0061815814
# --
# Elapsed time is 3.340956 seconds.
# Elapsed time is 1.097614 seconds.
# 27 [-0.328247] [5.1467667] 0.00013111036
# --
# Elapsed time is 3.313203 seconds.
# Elapsed time is 1.063334 seconds.
# 28 [-0.70752066] [8.118682] 0.0028589568
# --
# Elapsed time is 3.352121 seconds.
# Elapsed time is 1.066540 seconds.
# 29 [-5.5791554] [1.804028] 0.012180264
# --
# Elapsed time is 3.326398 seconds.
# Elapsed time is 1.100619 seconds.
# 30 [-6.0547805] [2.476889] 1e-04
# --
# Elapsed time is 3.337344 seconds.
# Elapsed time is 1.131364 seconds.
# 31 [-1.4780577] [0.48568374] 0.012769096
# --
# Elapsed time is 3.370426 seconds.
# Elapsed time is 0.992636 seconds.
# 32 [-0.8790758] [9.602204] 0.0064165173
# --
# Elapsed time is 3.381348 seconds.
# Elapsed time is 1.147123 seconds.
# 33 [-11.208873] [0.7538884] 0.021966333
# --
# Elapsed time is 3.408078 seconds.
# Elapsed time is 1.151031 seconds.
# 34 [0.2814473] [4.8418026] 0.00024243057
# --
# Elapsed time is 3.405684 seconds.
# Elapsed time is 1.147681 seconds.
# 35 [-0.2994827] [6.0602965] 0.004176905
# --
# Elapsed time is 3.468987 seconds.
# Elapsed time is 1.157965 seconds.
# 36 [-0.7357985] [8.31044] 0.0033416925
# --
# Elapsed time is 3.390860 seconds.
# Elapsed time is 1.157754 seconds.
# 37 [-0.63407475] [7.700856] 0.0063624117
# --
# Elapsed time is 3.369058 seconds.
# Elapsed time is 1.127534 seconds.
# 38 [-0.34155497] [5.9007163] 0.002581498
# --
# Elapsed time is 3.308612 seconds.
# Elapsed time is 1.130574 seconds.
# 39 [-0.44871157] [6.2376127] 0.006451254
# --
# Elapsed time is 3.363891 seconds.
# Elapsed time is 1.156041 seconds.
# 40 [-0.47057375] [6.5828967] 0.004026761
# --
# Elapsed time is 3.366247 seconds.
# Elapsed time is 1.159565 seconds.
# 41 [0.00958567] [5.058872] 0.00016835914
# --
# Elapsed time is 3.377168 seconds.
# Elapsed time is 1.147292 seconds.
# 42 [-0.745588] [8.019209] 0.006365854
# --
# Elapsed time is 3.381004 seconds.
# Elapsed time is 1.174973 seconds.
# 43 [-0.21146157] [5.7176056] 0.00044161323
# --
# Elapsed time is 3.395579 seconds.
# Elapsed time is 1.179131 seconds.
# 44 [-4.4784446] [8.334262] 0.005610151
# --
# Elapsed time is 3.384238 seconds.
# Elapsed time is 1.165399 seconds.
# 45 [-4.152508] [7.641506] 0.0010180151
# --
# Elapsed time is 3.400082 seconds.
# Elapsed time is 1.150221 seconds.
# 46 [-0.7552285] [8.235457] 0.0063051307
# --
# Elapsed time is 3.463027 seconds.
# Elapsed time is 1.171079 seconds.
# 47 [-0.41170144] [6.1333494] 0.0017821308
# --
# Elapsed time is 3.362894 seconds.
# Elapsed time is 1.177291 seconds.
# 48 [-5.1315746] [4.9016128] 0.00055790914
# --
# Elapsed time is 3.384289 seconds.
# Elapsed time is 1.165974 seconds.
# 49 [-5.0826545] [4.4893427] 0.00022732791
# --
# Elapsed time is 3.377692 seconds.
# Elapsed time is 1.172555 seconds.
# 50 [-0.95386094] [9.9520445] 0.00031098007
# --
# Elapsed time is 3.373821 seconds.
# Elapsed time is 1.194789 seconds.
# 51 [-4.3478146] [7.7864075] 0.0016711262
# --
# Elapsed time is 3.395526 seconds.
# Elapsed time is 1.198953 seconds.
# 52 [9.22164] [0.3843225] 0.0614182
# --
# Elapsed time is 3.488475 seconds.
# Elapsed time is 1.201621 seconds.
# 53 [-5.5246058] [0.10810997] 0.011498079
# --
# Elapsed time is 3.424060 seconds.
# Elapsed time is 1.151780 seconds.
# 54 [-0.4188469] [4.9911733] 0.003384007
# --
# Elapsed time is 3.398498 seconds.
# Elapsed time is 1.163576 seconds.
# 55 [7.417551] [0.023008] 0.0074731032
# --
# Elapsed time is 3.402557 seconds.
# Elapsed time is 1.182824 seconds.
# 56 [-0.34912068] [5.814181] 0.00237116
# --
# Elapsed time is 3.395454 seconds.
# Elapsed time is 1.189163 seconds.
# 57 [-0.69189256] [7.2562265] 0.0041521075
# --
# Elapsed time is 3.435174 seconds.
# Elapsed time is 1.213353 seconds.
# 58 [-0.7329752] [7.970033] 0.0042940215
# --
# Elapsed time is 3.437446 seconds.
# Elapsed time is 1.203841 seconds.
# 59 [-4.2252064] [8.32371] 0.00059713336
# --
# Elapsed time is 3.393292 seconds.
# Elapsed time is 0.575426 seconds.
# 60 [-0.1013375] [5.065038] 0.000615414
# --
# Elapsed time is 3.488643 seconds.
# Elapsed time is 1.194169 seconds.
# 61 [2.0359387] [0.8956593] 0.012227863
# --
# Elapsed time is 3.411429 seconds.
# Elapsed time is 1.138986 seconds.
# 62 [-1.0363295] [5.344902] 0.00033359003
# --
# Elapsed time is 3.391210 seconds.
# Elapsed time is 1.201515 seconds.
# 63 [-0.5455084] [6.4397793] 0.0004446468
# --
# Elapsed time is 3.428249 seconds.
# Elapsed time is 0.956199 seconds.
# 64 [-0.29657322] [5.7843533] 0.0003838018
# --
# Elapsed time is 3.471473 seconds.
# Elapsed time is 1.209333 seconds.
# 65 [-6.300011] [9.18409] 0.00086018
# --
# Elapsed time is 3.472854 seconds.
# Elapsed time is 1.208010 seconds.
# 66 [-0.22960429] [5.232346] 0.00058214966
# --
# Elapsed time is 3.465657 seconds.
# Elapsed time is 1.267652 seconds.
# 67 [1.8398517] [0.45462203] 0.007873404
# --
# Elapsed time is 3.562441 seconds.
# Elapsed time is 1.244500 seconds.
# 68 [-2.1821373] [5.9566154] 0.00058897265
# --
# Elapsed time is 3.523611 seconds.
# Elapsed time is 1.252656 seconds.
# 69 [-4.2848587] [5.7796717] 0.00092030864
# --
# Elapsed time is 3.511640 seconds.
# Elapsed time is 1.207855 seconds.
# 70 [-2.4973233] [8.085115] 0.0016594152
# --
# Elapsed time is 3.391454 seconds.
# Elapsed time is 1.216919 seconds.
# 71 [-2.437507] [7.751434] 0.0019049571
# --
# Elapsed time is 3.510094 seconds.
# Elapsed time is 1.231726 seconds.
# 72 [-2.5107455] [8.037478] 0.0026116825
# --
# Elapsed time is 3.500521 seconds.
# Elapsed time is 1.215498 seconds.
# 73 [-4.3017855] [7.159545] 0.0005331321
# --
# Elapsed time is 3.479840 seconds.
# Elapsed time is 1.209787 seconds.
# 74 [-5.525405] [3.8557506] 0.00087199366
# --
# Elapsed time is 3.476018 seconds.
# Elapsed time is 1.235210 seconds.
# 75 [-4.3203936] [7.6822834] 0.0006691113
# --
# Elapsed time is 3.478461 seconds.
# Elapsed time is 1.256318 seconds.
# 76 [-2.4216464] [7.9700623] 0.0013088447
# --
# Elapsed time is 3.597966 seconds.
# Elapsed time is 1.230243 seconds.
# 77 [-0.539358] [6.579922] 0.0016770092
# --
# Elapsed time is 3.585668 seconds.
# Elapsed time is 1.223896 seconds.
# 78 [8.755832] [2.8074317] 0.009954309
# --
# Elapsed time is 3.473350 seconds.
# Elapsed time is 1.234938 seconds.
# 79 [-5.510621] [2.030226] 0.0027954984
# --
# Elapsed time is 3.503076 seconds.
# Elapsed time is 1.241602 seconds.
# 80 [-1.6064813] [5.511863] 0.0015736959
# --
# Elapsed time is 3.466711 seconds.
# Elapsed time is 0.991545 seconds.
# 81 [-1.5357416] [0.45958632] 0.006396459
# --
# Elapsed time is 3.489054 seconds.
# Elapsed time is 1.276219 seconds.
# 82 [-0.627219] [6.6724863] 1e-04
# --
# Elapsed time is 3.555681 seconds.
# Elapsed time is 1.261147 seconds.
# 83 [-0.60941285] [6.760826] 0.00041437647
# --
# Elapsed time is 3.516704 seconds.
# Elapsed time is 1.195331 seconds.
# 84 [-0.61188996] [4.3117733] 0.00043700915
# --
# Elapsed time is 3.462732 seconds.
# Elapsed time is 1.186153 seconds.
# 85 [-5.4523067] [3.910352] 0.0008826055
# --
# Elapsed time is 3.470843 seconds.
# Elapsed time is 1.125747 seconds.
# 86 [-1.3858092] [1.3389118] 0.0012778944
# --
# Elapsed time is 3.384019 seconds.
# Elapsed time is 1.167889 seconds.
# 87 [8.047943] [0.12085029] 0.015677888
# --
# Elapsed time is 3.401974 seconds.
# Elapsed time is 1.169540 seconds.
# 88 [-4.9115705] [6.0212293] 0.0004622505
# --
# Elapsed time is 3.409635 seconds.
# Elapsed time is 1.179400 seconds.
# 89 [-4.352472] [9.202906] 0.0007555389
# --
# Elapsed time is 3.427757 seconds.
# Elapsed time is 1.205126 seconds.
# 90 [-4.8149347] [0.077543] 0.0070885657
# --
# Elapsed time is 3.442349 seconds.
# Elapsed time is 1.244184 seconds.
# 91 [-0.590346] [6.5434976] 0.0010654682
# --
# Elapsed time is 3.413727 seconds.
# Elapsed time is 1.192275 seconds.
# 92 [-0.6909571] [7.3404126] 0.0028882015
# --
# Elapsed time is 3.448495 seconds.
# Elapsed time is 1.207246 seconds.
# 93 [-0.9757519] [9.617843] 0.0003463825
# --
# Elapsed time is 3.450119 seconds.
# Elapsed time is 0.942648 seconds.
# 94 [-5.2612944] [4.4353933] 0.00013397765
# --
# Elapsed time is 3.469641 seconds.
# Elapsed time is 1.265258 seconds.
# 95 [-0.6268977] [7.134534] 0.0031450333
# --
# Elapsed time is 3.660202 seconds.
# Elapsed time is 0.965366 seconds.
# 96 [8.897668] [2.4546103] 0.000121337966
# --
# Elapsed time is 3.524029 seconds.
# Elapsed time is 1.273113 seconds.
# 97 [-4.4821653] [8.132082] 0.00129745
# --
# Elapsed time is 3.534244 seconds.
# Elapsed time is 0.610599 seconds.
# 98 [-0.4192394] [6.2822914] 1e-04
# --
# Elapsed time is 3.498539 seconds.
# Elapsed time is 1.256728 seconds.
# 99 [-0.4638828] [6.1679606] 0.0008523769
# --
# Elapsed time is 3.536488 seconds.
# Elapsed time is 1.300207 seconds.
# 100 [-4.9646997] [4.675238] 0.00027674608
# --
# Elapsed time is 3.551551 seconds.
# Elapsed time is 1.307284 seconds.
# 101 [-0.6458544] [7.2358294] 0.002125546
# --
# Elapsed time is 3.594271 seconds.
# Elapsed time is 1.269294 seconds.
# 102 [-0.24755424] [5.069184] 0.0018382974
# --
# Elapsed time is 3.486201 seconds.
# Elapsed time is 1.280168 seconds.
# 103 [7.773825] [4.943507] 1e-04
# --
# Elapsed time is 3.532340 seconds.
# Elapsed time is 1.290131 seconds.
# 104 [-10.822232] [2.9069116] 0.00011103446
# --
# Elapsed time is 3.495626 seconds.
# Elapsed time is 1.305965 seconds.
# 105 [8.801969] [1.4990298] 0.0004014108
# --
# Elapsed time is 3.573198 seconds.
# Elapsed time is 1.196368 seconds.
# 106 [-5.376713] [4.669416] 0.00010139129
# --
# Elapsed time is 3.471253 seconds.
# Elapsed time is 1.210406 seconds.
# 107 [-5.929321] [9.009608] 0.00018563421
# --
# Elapsed time is 3.483857 seconds.
# Elapsed time is 1.202813 seconds.
# 108 [-4.628713] [5.9258094] 0.00044231987
# --
# Elapsed time is 3.509762 seconds.
# Elapsed time is 1.228615 seconds.
# 109 [-4.378161] [7.498264] 0.0009921112
# --
# Elapsed time is 3.541173 seconds.
# Elapsed time is 1.154975 seconds.
# 110 [-4.724382] [6.188613] 0.0005976
# --
# Elapsed time is 3.433950 seconds.
# Elapsed time is 1.186689 seconds.
# 111 [-4.3856525] [7.177136] 0.00039552758
# --
# Elapsed time is 3.428394 seconds.
# Elapsed time is 0.533263 seconds.
# 112 [-4.0316224] [5.517012] 0.00037341102
# --
# Elapsed time is 3.434919 seconds.
# Elapsed time is 1.185584 seconds.
# 113 [-0.5948343] [7.123114] 0.0021659038
# --
# Elapsed time is 3.478243 seconds.
# Elapsed time is 1.198110 seconds.
# 114 [-1.9873222] [0.00580391] 0.005407389
# --
# Elapsed time is 3.483472 seconds.
# Elapsed time is 1.207294 seconds.
# 115 [-4.0805583] [7.224152] 0.00059089466
# --
# Elapsed time is 3.482372 seconds.
# Elapsed time is 1.369912 seconds.
# 116 [-6.0817046] [1.1438851] 0.0024085674
# --
# Elapsed time is 3.471846 seconds.
# Elapsed time is 1.196019 seconds.
# 117 [-11.201658] [2.0886526] 0.0023177003
# --
# Elapsed time is 3.467328 seconds.
# Elapsed time is 1.173259 seconds.
# 118 [-3.8712232] [6.956214] 0.0004497502
# --
# Elapsed time is 3.442728 seconds.
# Elapsed time is 1.176033 seconds.
# 119 [-4.1099644] [5.9790907] 0.0006765521
# --
# Elapsed time is 3.447499 seconds.
# Elapsed time is 0.772310 seconds.
# 120 [-0.84838474] [8.934776] 0.00046898134
# --
# Elapsed time is 3.468582 seconds.
# Elapsed time is 1.196945 seconds.
# 121 [7.9543786] [6.193842] 1e-04
# --
# Elapsed time is 3.502798 seconds.
# Elapsed time is 1.197831 seconds.
# 122 [-0.70256484] [7.8976803] 0.00061540643
# --
# Elapsed time is 3.508315 seconds.
# Elapsed time is 0.907443 seconds.
# 123 [-0.8315505] [8.254717] 0.0012433695
# --
# Elapsed time is 3.490147 seconds.
# Elapsed time is 1.192156 seconds.
# 124 [8.604375] [2.76629] 0.00013877582
# --
# Elapsed time is 3.501003 seconds.
# Elapsed time is 1.217055 seconds.
# 125 [-2.5205798] [8.60622] 0.0018881019
# --
# Elapsed time is 3.498742 seconds.
# Elapsed time is 1.295644 seconds.
# 126 [8.636661] [2.77344] 1e-04
# --
# Elapsed time is 3.568553 seconds.
# Elapsed time is 1.371804 seconds.
# 127 [-4.014138] [5.187299] 0.00045874921
# --
# Elapsed time is 3.651973 seconds.
# Elapsed time is 1.372442 seconds.
# 128 [-4.815469] [6.5274687] 1e-04
# --
# Elapsed time is 3.709576 seconds.
# Elapsed time is 1.232208 seconds.
# 129 [-4.95043] [6.0707364] 1e-04
# --
# Elapsed time is 3.544760 seconds.
# Elapsed time is 1.226490 seconds.
# 130 [-0.23541693] [4.395363] 0.00014468328
# --
# Elapsed time is 3.544241 seconds.
# Elapsed time is 1.247525 seconds.
# 131 [-10.01716] [5.090244] 1e-04
# --
# Elapsed time is 3.593392 seconds.
# Elapsed time is 1.241760 seconds.
# 132 [-6.089313] [0.00179504] 0.0010767193
# --
# Elapsed time is 3.579747 seconds.
# Elapsed time is 1.214865 seconds.
# 133 [-4.6927285] [5.3232036] 0.00041775138
# --
# Elapsed time is 3.598258 seconds.
# Elapsed time is 1.228111 seconds.
# 134 [-0.610389] [7.160828] 0.0025214027
# --
# Elapsed time is 3.568240 seconds.
# Elapsed time is 1.241824 seconds.
# 135 [-0.7292122] [7.7517157] 0.0009930461
# --
# Elapsed time is 3.532267 seconds.
# Elapsed time is 0.807151 seconds.
# 136 [-2.5997589] [9.2614155] 0.00090506894
# --
# Elapsed time is 3.571412 seconds.
# Elapsed time is 1.246589 seconds.
# 137 [-4.160648] [7.487014] 0.0002953544
# --
# Elapsed time is 3.596030 seconds.
# Elapsed time is 1.259852 seconds.
# 138 [-6.165219] [0.70735246] 0.001977222
# --
# Elapsed time is 3.787651 seconds.
# Elapsed time is 1.261601 seconds.
# 139 [8.372367] [3.8758483] 1e-04
# --
# Elapsed time is 3.583195 seconds.
# Elapsed time is 0.800759 seconds.
# 140 [-0.6401508] [7.275148] 0.0005472523
# --
# Elapsed time is 3.637509 seconds.
# Elapsed time is 1.252607 seconds.
# 141 [8.677797] [2.999032] 0.00016474273
# --
# Elapsed time is 3.611195 seconds.
# Elapsed time is 1.218852 seconds.
# 142 [-0.31689247] [5.42027] 0.0005781473
# --
# Elapsed time is 3.613107 seconds.
# Elapsed time is 1.246578 seconds.
# 143 [-0.8793759] [9.07386] 0.00067895756
# --
# Elapsed time is 3.633994 seconds.
# Elapsed time is 1.234577 seconds.
# 144 [-0.28445145] [5.1700754] 0.0006535315
# --
# Elapsed time is 3.614462 seconds.
# Elapsed time is 0.595105 seconds.
# 145 [-0.7064843] [7.949036] 0.00031660096
# --
# Elapsed time is 3.627157 seconds.
# Elapsed time is 1.250513 seconds.
# 146 [-0.6221304] [7.1386766] 0.002258865
# --
# Elapsed time is 3.619133 seconds.
# Elapsed time is 1.245834 seconds.
# 147 [-7.1426888] [0.00984917] 0.0016683721
# --
# Elapsed time is 3.661051 seconds.
# Elapsed time is 1.269828 seconds.
# 148 [7.936055] [6.0235705] 1e-04
# --
# Elapsed time is 3.692795 seconds.
# Elapsed time is 1.268111 seconds.
# 149 [8.779462] [2.5491693] 1e-04
# --
# Elapsed time is 3.666935 seconds.
# Elapsed time is 1.254468 seconds.
# 150 [-0.7649119] [8.916329] 0.0013818756
# --
# Elapsed time is 3.652905 seconds.
# Elapsed time is 1.250162 seconds.
# 151 [-0.2982329] [5.8926873] 0.00050854514
# --
# Elapsed time is 3.652540 seconds.
# Elapsed time is 1.286249 seconds.
# 152 [-0.3584254] [5.675774] 0.0005232472
# --
# Elapsed time is 3.619694 seconds.
# Elapsed time is 1.257091 seconds.
# 153 [8.485758] [3.4270978] 1e-04
# --
# Elapsed time is 3.655425 seconds.
# Elapsed time is 1.280159 seconds.
# 154 [-0.68377745] [7.3254194] 0.0009232605
# --
# Elapsed time is 3.679481 seconds.
# Elapsed time is 1.290271 seconds.
# 155 [-0.3981292] [5.4517374] 0.00023208254
# --
# Elapsed time is 3.718992 seconds.
# Elapsed time is 1.294604 seconds.
# 156 [-3.9896529] [7.0163827] 0.0002799861
# --
# Elapsed time is 3.685622 seconds.
# Elapsed time is 1.295487 seconds.
# 157 [-0.48303387] [6.4127803] 0.0008463137
# --
# Elapsed time is 3.689654 seconds.
# Elapsed time is 0.462256 seconds.
# 158 [-0.43236664] [6.294037] 0.00010005533
# --
# Elapsed time is 3.532897 seconds.
# Elapsed time is 0.874443 seconds.
# 159 [-4.6777344] [5.4587626] 0.00019448856
# --
# Elapsed time is 3.581790 seconds.
# Elapsed time is 1.215307 seconds.
# 160 [8.416723] [3.4403925] 1e-04
# --
# Elapsed time is 3.576601 seconds.
# Elapsed time is 1.174597 seconds.
# 161 [-0.6597714] [7.0199633] 0.0009106836
# --
# Elapsed time is 3.567907 seconds.
# Elapsed time is 1.219813 seconds.
# 162 [1.647066] [1.4648533] 0.003040386
# --
# Elapsed time is 3.809701 seconds.
# Elapsed time is 1.242435 seconds.
# 163 [-4.31534] [9.60829] 0.00084144657
# --
# Elapsed time is 3.604816 seconds.
# Elapsed time is 1.253298 seconds.
# 164 [-0.49201882] [6.398356] 0.00031202665
# --
# Elapsed time is 3.616384 seconds.
# Elapsed time is 1.020098 seconds.
# 165 [-9.485665] [4.581434] 1e-04
# --
# Elapsed time is 3.615488 seconds.
# Elapsed time is 1.222609 seconds.
# 166 [2.0434172] [0.5788633] 0.0048949886
# --
# Elapsed time is 3.610895 seconds.
# Elapsed time is 1.245599 seconds.
# 167 [-8.616485] [5.6639028] 1e-04
# --
# Elapsed time is 3.604796 seconds.
# Elapsed time is 1.258083 seconds.
# 168 [8.384422] [3.5810273] 1e-04
# --
# Elapsed time is 3.617208 seconds.
# Elapsed time is 1.262701 seconds.
# 169 [-2.2524369] [6.224428] 0.00046589453
# --
# Elapsed time is 3.622121 seconds.
# Elapsed time is 1.275456 seconds.
# 170 [-0.47167686] [6.5411735] 0.00055886264
# --
# Elapsed time is 3.655555 seconds.
# Elapsed time is 1.264619 seconds.
# 171 [-0.92412174] [9.359583] 0.00027374693
# --
# Elapsed time is 3.652971 seconds.
# Elapsed time is 1.259433 seconds.
# 172 [-2.2677224] [6.2015224] 0.0001832162
# --
# Elapsed time is 3.655889 seconds.
# Elapsed time is 1.288381 seconds.
# 173 [-11.58094] [0.5579127] 0.008772161
# --
# Elapsed time is 3.665250 seconds.
# Elapsed time is 1.265459 seconds.
# 174 [-0.85705614] [5.373086] 0.00027842974
# --
# Elapsed time is 3.725662 seconds.
# Elapsed time is 1.248915 seconds.
# 175 [8.585771] [2.9907045] 0.00016502608
# --
# Elapsed time is 3.673301 seconds.
# Elapsed time is 1.267324 seconds.
# 176 [-2.5987535] [8.998921] 0.0019957125
# --
# Elapsed time is 3.669452 seconds.
# Elapsed time is 1.255311 seconds.
# 177 [-4.1118503] [6.914232] 0.0003273082
# --
# Elapsed time is 3.669922 seconds.
# Elapsed time is 1.292252 seconds.
# 178 [-2.172229] [6.9378934] 0.0011336072
# --
# Elapsed time is 3.673013 seconds.
# Elapsed time is 1.296396 seconds.
# 179 [-0.34448335] [5.158629] 0.00080471224
# --
# Elapsed time is 3.687306 seconds.
# Elapsed time is 1.301801 seconds.
# 180 [-0.6529322] [6.7563195] 0.0006667283
# --
# Elapsed time is 3.697594 seconds.
# Elapsed time is 1.287415 seconds.
# 181 [-4.256739] [8.428123] 0.0005485959
# --
# Elapsed time is 3.675425 seconds.
# Elapsed time is 1.301601 seconds.
# 182 [-0.8842415] [9.046841] 0.00038791282
# --
# Elapsed time is 3.676867 seconds.
# Elapsed time is 1.273287 seconds.
# 183 [-0.69119585] [7.710877] 0.0014572456
# --
# Elapsed time is 3.681273 seconds.
# Elapsed time is 1.298262 seconds.
# 184 [-0.772584] [8.215202] 0.0013946849
# --
# Elapsed time is 3.719281 seconds.
# Elapsed time is 1.315044 seconds.
# 185 [-7.5301456] [7.5867357] 0.00016535539
# --
# Elapsed time is 3.730037 seconds.
# Elapsed time is 1.323773 seconds.
# 186 [-4.086671] [5.809206] 0.00039576166
# --
# Elapsed time is 3.740283 seconds.
# Elapsed time is 1.317974 seconds.
# 187 [-2.6054204] [8.023513] 0.0010051681
# --
# Elapsed time is 3.783522 seconds.
# Elapsed time is 1.315187 seconds.
# 188 [-4.36229] [7.6744504] 0.0001697474
# --
# Elapsed time is 3.954273 seconds.
# Elapsed time is 1.329398 seconds.
# 189 [-0.7265113] [7.808704] 0.002018711
# --
# Elapsed time is 3.754804 seconds.
# Elapsed time is 1.223667 seconds.
# 190 [-8.127246] [8.077714] 0.00021528399
# --
# Elapsed time is 3.654368 seconds.
# Elapsed time is 1.289503 seconds.
# 191 [-4.3175225] [7.924369] 0.00029231003
# --
# Elapsed time is 3.703656 seconds.
# Elapsed time is 1.232183 seconds.
# 192 [-3.8013089] [6.237937] 0.00031112594
# --
# Elapsed time is 3.649844 seconds.
# Elapsed time is 1.273228 seconds.
# 193 [-0.44509795] [5.58263] 0.00027722205
# --
# Elapsed time is 3.642668 seconds.
# Elapsed time is 1.242073 seconds.
# 194 [-0.77098787] [8.530761] 0.0013269488
# --
# Elapsed time is 3.660445 seconds.
# Elapsed time is 1.266168 seconds.
# 195 [8.232507] [0.8792637] 0.0012176026
# --
# Elapsed time is 3.688632 seconds.
# Elapsed time is 1.254244 seconds.
# 196 [9.124961] [2.0542421] 1e-04
# --
# Elapsed time is 3.649538 seconds.
# Elapsed time is 1.277092 seconds.
# 197 [1.8223351] [0.02838399] 0.0032504466
# --
# Elapsed time is 3.819353 seconds.
# Elapsed time is 1.264414 seconds.
# 198 [-4.4196734] [9.255181] 0.0011965295
# --
# Elapsed time is 3.682140 seconds.
# Elapsed time is 1.283180 seconds.
# 199 [-2.3486376] [6.4156356] 0.00020078404
# --
# Elapsed time is 3.683144 seconds.
# Elapsed time is 1.251748 seconds.
# 200 [-3.924724] [5.601512] 0.0002429839
# --
# Elapsed time is 3.730593 seconds.
# Elapsed time is 1.267440 seconds.
# 201 [-0.88250536] [5.272671] 0.0003934011
# --
# Elapsed time is 3.722442 seconds.
# Elapsed time is 1.317676 seconds.
# 202 [-0.39992467] [6.082621] 0.00042615985
# --
# Elapsed time is 3.737607 seconds.
# Elapsed time is 1.283430 seconds.
# 203 [-0.7530316] [8.220625] 0.000488194
# --
# Elapsed time is 3.730045 seconds.
# Elapsed time is 1.297700 seconds.
# 204 [-0.32986712] [6.454731] 0.00088066614
# --
# Elapsed time is 3.747076 seconds.
# Elapsed time is 1.288741 seconds.
# 205 [-4.8021355] [5.559393] 0.00016964485
# --
# Elapsed time is 3.715989 seconds.
# Elapsed time is 1.247921 seconds.
# 206 [-4.37319] [8.397533] 0.00038150203
# --
# Elapsed time is 3.659203 seconds.
# Elapsed time is 1.281942 seconds.
# 207 [-0.6796522] [7.2836027] 0.0001699135
# --
# Elapsed time is 3.725516 seconds.
# Elapsed time is 1.288807 seconds.
# 208 [-8.41897] [6.104826] 1e-04
# --
# Elapsed time is 3.722802 seconds.
# Elapsed time is 1.280821 seconds.
# 209 [-1.985113] [5.5121765] 0.0008309031
# --
# Elapsed time is 3.732028 seconds.
# Elapsed time is 1.294304 seconds.
# 210 [-4.128859] [7.1173215] 0.00017228092
# --
# Elapsed time is 3.715311 seconds.
# Elapsed time is 1.281998 seconds.
# 211 [-0.88512963] [9.299854] 0.00035882698
# --
# Elapsed time is 3.727693 seconds.
# Elapsed time is 1.294849 seconds.
# 212 [8.946259] [1.5901198] 0.0009975886
# --
# Elapsed time is 3.726371 seconds.
# Elapsed time is 1.300177 seconds.
# 213 [-2.1623483] [6.3425713] 0.0008351449
# --
# Elapsed time is 3.679124 seconds.
# Elapsed time is 1.302173 seconds.
# 214 [-2.1071472] [7.34447] 0.00049402274
# --
# Elapsed time is 3.742756 seconds.
# Elapsed time is 1.171374 seconds.
# 215 [-10.4286585] [3.4063046] 0.000119603304
# --
# Elapsed time is 3.744148 seconds.
# Elapsed time is 1.317269 seconds.
# 216 [-11.167489] [3.1856794] 0.00015497087
# --
# Elapsed time is 4.016069 seconds.
# Elapsed time is 0.911138 seconds.
# 217 [-4.1531773] [7.313866] 0.00019705901
# --
# Elapsed time is 3.761305 seconds.
# Elapsed time is 1.327998 seconds.
# 218 [0.36718822] [3.1913865] 0.0007576255
# --
# Elapsed time is 3.791287 seconds.
# Elapsed time is 1.326497 seconds.
# 219 [-0.79985374] [8.153832] 0.0009186611
# --
# Elapsed time is 3.775687 seconds.
# Elapsed time is 0.845216 seconds.
# 220 [-5.702252] [0.49134213] 0.0006968938
# --
# Elapsed time is 3.830021 seconds.
# Elapsed time is 1.332727 seconds.
# 221 [-2.5711215] [8.898122] 0.0007780372
# --
# Elapsed time is 3.763159 seconds.
# Elapsed time is 1.217846 seconds.
# 222 [-0.6252391] [7.560704] 0.001087086
# --
# Elapsed time is 3.603638 seconds.
# Elapsed time is 1.376724 seconds.
# 223 [-1.1073564] [0.00285744] 0.0034245339
# --
# Elapsed time is 3.691418 seconds.
# Elapsed time is 1.377173 seconds.
# 224 [-3.5823104] [5.90138] 0.0003092479
# --
# Elapsed time is 3.713359 seconds.
# Elapsed time is 1.396626 seconds.
# 225 [-2.613052] [9.279837] 0.0007881709
# --
# Elapsed time is 3.712871 seconds.
# Elapsed time is 1.392515 seconds.
# 226 [-11.558273] [0.9700753] 0.0026397884
# --
# Elapsed time is 3.747564 seconds.
# Elapsed time is 1.400466 seconds.
# 227 [-0.47916174] [7.4015756] 0.00039512603
# --
# Elapsed time is 3.740679 seconds.
# Elapsed time is 1.393516 seconds.
# 228 [-4.45894] [8.124966] 0.00069925055
# --
# Elapsed time is 3.722682 seconds.
# Elapsed time is 1.388917 seconds.
# 229 [-4.5034075] [7.847631] 0.00059917377
# --
# Elapsed time is 3.731746 seconds.
# Elapsed time is 1.392317 seconds.
# 230 [-4.336751] [7.458982] 0.0005044357
# --
# Elapsed time is 3.705566 seconds.
# Elapsed time is 1.411850 seconds.
# 231 [-5.648112] [0.6516912] 0.0011893265
# --
# Elapsed time is 3.721855 seconds.
# Elapsed time is 1.388482 seconds.
# 232 [-0.78173864] [7.272143] 0.00080560084
# --
# Elapsed time is 3.704190 seconds.
# Elapsed time is 1.402080 seconds.
# 233 [-3.7685442] [7.09702] 0.00018069809
# --
# Elapsed time is 3.742956 seconds.
# Elapsed time is 1.403368 seconds.
# 234 [-0.7421088] [8.394474] 0.00048112276
# --
# Elapsed time is 3.742359 seconds.
# Elapsed time is 1.424330 seconds.
# 235 [-1.7305058] [5.831265] 0.000631424
# --
# Elapsed time is 3.768208 seconds.
# Elapsed time is 1.414824 seconds.
# 236 [-10.46491] [3.0997033] 0.00017380161
# --
# Elapsed time is 3.759336 seconds.
# Elapsed time is 1.443640 seconds.
# 237 [7.889026] [5.6539173] 1e-04
# --
# Elapsed time is 3.770541 seconds.
# Elapsed time is 1.407899 seconds.
# 238 [-0.37527743] [5.1933575] 0.00022727443
# --
# Elapsed time is 3.740583 seconds.
# Elapsed time is 1.407786 seconds.
# 239 [-0.89019704] [9.197081] 0.00024422933
# --
# Elapsed time is 3.763143 seconds.
# Elapsed time is 1.423681 seconds.
# 240 [8.895525] [1.6559336] 0.00016719854
# --
# Elapsed time is 3.790701 seconds.
# Elapsed time is 1.417317 seconds.
# 241 [-4.311454] [9.382591] 0.0009446912
# --
# Elapsed time is 3.771694 seconds.
# Elapsed time is 1.444892 seconds.
# 242 [-0.85107887] [8.456996] 0.0005203478
# --
# Elapsed time is 3.740460 seconds.
# Elapsed time is 1.463333 seconds.
# 243 [-4.270407] [7.5113463] 0.0004489168
# --
# Elapsed time is 3.837205 seconds.
# Elapsed time is 1.445963 seconds.
# 244 [-2.199401] [0.00270566] 0.0028368759
# --
# Elapsed time is 3.813749 seconds.
# Elapsed time is 1.438611 seconds.
# 245 [7.95224] [4.858711] 1e-04
# --
# Elapsed time is 3.831529 seconds.
# Elapsed time is 1.409897 seconds.
# 246 [-0.66254413] [7.506169] 0.00045246762
# --
# Elapsed time is 3.805967 seconds.
# Elapsed time is 1.433070 seconds.
# 247 [-0.4182793] [5.79323] 0.00077241356
# --
# Elapsed time is 3.494975 seconds.
# Elapsed time is 1.449248 seconds.
# 248 [-0.88133246] [9.150635] 0.00024254803
# --
# Elapsed time is 3.802173 seconds.
# Elapsed time is 1.467875 seconds.
# 249 [-1.814637] [0.00043497] 0.0013264207
# --
# Elapsed time is 3.811129 seconds.
# Elapsed time is 1.457671 seconds.
# 250 [-3.5735936] [6.232378] 0.00024145265
# --
# Elapsed time is 3.771115 seconds.
# Elapsed time is 1.435987 seconds.
# 251 [-5.9875326] [0.7139195] 0.00082225
# --
# Elapsed time is 3.843067 seconds.
# Elapsed time is 1.442809 seconds.
# 252 [-3.8795197] [5.908719] 0.000102800375
# --
# Elapsed time is 3.822770 seconds.
# Elapsed time is 1.478646 seconds.
# 253 [-4.9597626] [4.8984423] 0.00011289337
# --
# Elapsed time is 3.843965 seconds.
# Elapsed time is 1.377285 seconds.
# 254 [8.728269] [2.6827657] 1e-04
# --
# Elapsed time is 3.698555 seconds.
# Elapsed time is 1.258027 seconds.
# 255 [-3.4439528] [5.5019507] 0.00012983948
# --
# Elapsed time is 3.712949 seconds.
# Elapsed time is 1.237963 seconds.
# 256 [-5.5478463] [5.0555835] 1e-04
# --
# Elapsed time is 3.714074 seconds.
# Elapsed time is 1.270667 seconds.
# 257 [2.162835] [0.60815173] 0.0027678253
# --
# Elapsed time is 3.708934 seconds.
# Elapsed time is 1.256117 seconds.
# 258 [-4.3881173] [5.590727] 0.00020371527
# --
# Elapsed time is 3.737147 seconds.
# Elapsed time is 1.261626 seconds.
# 259 [-0.74697274] [7.4482026] 0.000713991
# --
# Elapsed time is 3.738427 seconds.
# Elapsed time is 1.263732 seconds.
# 260 [-0.7115354] [7.6169014] 0.00028270212
# --
# Elapsed time is 3.785414 seconds.
# Elapsed time is 1.237817 seconds.
# 261 [-6.2986383] [9.186321] 0.000100743826
# --
# Elapsed time is 3.713856 seconds.
# Elapsed time is 1.247401 seconds.
# 262 [-11.598749] [1.4166335] 0.00044658277
# --
# Elapsed time is 3.761627 seconds.
# Elapsed time is 1.284776 seconds.
# 263 [-4.1959133] [7.488186] 1e-04
# --
# Elapsed time is 3.752571 seconds.
# Elapsed time is 1.268396 seconds.
# 264 [-1.5345501] [5.8439064] 0.00018769907
# --
# Elapsed time is 3.766695 seconds.
# Elapsed time is 0.686278 seconds.
# 265 [-0.7172997] [4.333674] 0.00012774332
# --

# %%
logprobgp = bvbq.gp.SimpleGP(1,kind='smatern32',noise=0,zeromax=True)
logprobgp.mean = -20.0
logprobgp.noise = data['noise']
logprobgp.lengthscale = data['lengthscale']
logprobgp.theta = data['outputscale']
logprobgp.set_data(data['X'],data['y'].flatten(),empirical_params=False)
# logprobgp.optimize_params()

# %%
res

# %%
boostdistrib = bvbq.distributions.MixtureDiagonalNormalDistribution(mixmeans,mixvars,mixweights)
xplot = np.linspace(-20,20,201).reshape(-1,1)
yplot1 = logprob_mixgaussians(xplot)
yplot2 = logprobgp.predict(xplot,return_cov=False)
yplot3 = boostdistrib.logprob(xplot).reshape(-1,1)
plt.plot(xplot,jnp.exp(yplot1),'b')
plt.plot(xplot,jnp.exp(yplot2),'r')
plt.plot(xplot,jnp.exp(yplot3),'g')

# %%
mixmeans
# Out:
# DeviceArray([[ -1.960696  ],
#              [-21.302664  ],
#              [ -7.475327  ],
#              [ -7.8455486 ],
#              [  7.0041175 ],
#              [ -8.77343   ],
#              [ -3.9261105 ],
#              [ -4.515048  ],
#              [ -4.2821555 ],
#              [ -3.8855982 ],
#              [ -2.9858692 ],
#              [ -5.014992  ],
#              [ -8.516691  ],
#              [ -5.443662  ],
#              [ -5.4247546 ],
#              [ -6.974314  ],
#              [ -1.8054025 ],
#              [ -5.5780435 ],
#              [ -5.086027  ],
#              [ -6.221151  ],
#              [ -0.5384201 ],
#              [ -1.5548795 ],
#              [ -2.3095999 ],
#              [  1.9781837 ],
#              [ -7.5360165 ],
#              [ -3.2856658 ],
#              [ -5.0841985 ],
#              [ -6.8157225 ],
#              [ -2.3189285 ],
#              [  3.0821881 ],
#              [  0.78526586],
#              [ -2.5410705 ],
#              [ -3.5567799 ],
#              [  0.8251402 ],
#              [ -5.194584  ],
#              [ -2.2061424 ],
#              [ -4.2449985 ],
#              [ -1.2597004 ],
#              [ -3.0945582 ],
#              [ -4.5935745 ],
#              [ -2.2045815 ],
#              [ -6.202866  ],
#              [ -7.462238  ],
#              [  2.3694272 ],
#              [ -2.2954717 ],
#              [ -1.7401667 ],
#              [ -1.7354925 ],
#              [ -2.8313549 ],
#              [ -8.633031  ],
#              [ -8.387536  ],
#              [  0.34981006],
#              [ -4.63822   ],
#              [ -1.4596733 ],
#              [ -1.0254431 ],
#              [ -6.7487464 ],
#              [-11.357965  ],
#              [  0.8459222 ],
#              [  1.2211432 ],
#              [  2.8366034 ],
#              [ -8.661534  ],
#              [ -6.853059  ],
#              [-11.723056  ],
#              [  3.05757   ],
#              [ -0.07170311],
#              [ -2.1680052 ],
#              [ -3.7649696 ],
#              [ -4.3333387 ],
#              [  7.9983974 ],
#              [ -1.4953631 ],
#              [ -1.8211309 ],
#              [ -7.6520443 ],
#              [ -2.756396  ],
#              [ -1.7508401 ],
#              [ -3.167957  ],
#              [ -4.3160267 ],
#              [ -4.22222   ],
#              [ -7.9371862 ],
#              [ -8.072983  ],
#              [ -3.6975763 ],
#              [ -6.559893  ],
#              [ -7.591917  ],
#              [ -1.8407887 ],
#              [ -0.3596267 ],
#              [ -7.8050528 ],
#              [ 14.847865  ],
#              [ -5.189559  ],
#              [ -2.101745  ],
#              [ -2.459342  ],
#              [ -0.35830706],
#              [ -2.5013676 ],
#              [ -7.348019  ],
#              [  3.216321  ],
#              [  3.414846  ],
#              [ -3.0868971 ],
#              [-27.488693  ],
#              [ -8.439203  ],
#              [ -2.0685787 ],
#              [ -0.06136156],
#              [  7.1988587 ],
#              [  2.9426742 ],
#              [ -4.0947    ]], dtype=float32)

# %%
func_and_grad_relbo(params,mixmeans,mixvars,mixweights,-20,-1.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0b7b14ad59bc> in <module>
# ----> 1 func_and_grad_relbo(params,mixmeans,mixvars,mixweights,-20,-1.0)
#
# NameError: name 'mixmeans' is not defined

# %%
subkey,key = jax.random.split(key)
func_and_grad_gradboost(weight,mean,var,mixmeans,mixvars,mixweights,subkey)
# Out:
# (DeviceArray(0.7377595, dtype=float32), DeviceArray(-1.0448856, dtype=float32))

# %%
mcbq_mixdmvn_gradboost_delbodw(weight,logprobgp,mean,var,mixmeans,mixvars,mixweights,subkey,nsamples=100)
# Out:
# DeviceArray(0.92413974, dtype=float32)
