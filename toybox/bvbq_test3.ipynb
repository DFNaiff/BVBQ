# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

import collections
import functools
import abc
import random

import numpy as np
import jax
import jax.numpy as jnp
import jax.experimental.optimizers
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import sobol_seq

import bvbq
# import bvbq.gp
# import bvbq.bvi
# import bvbq.distributions

# %%
ndim = 2
def exponential_quartic(x):
    x1,x2 = x[...,0],x[...,1]
    res = -0.1*x1**4 -0.5*(2*x2-x1**2)**2
#     return -0.5*((x1+1)**2 + (x2 - 1)**2)
    return res

# %%
def test_function(params):
    x = params['x']
    return jnp.sum(x**2)

learning_rate = 1e-1
optwrapper = bvbq.optwrapper.JaxOptWrapper("adam",learning_rate)
optwrapper.init({'x':jnp.ones(2)},jax.value_and_grad(test_function))
for i in range(50):
    value,_ = optwrapper.step()
#     print(value)
print(optwrapper.params)
# Out:
# {'x': DeviceArray([-0.00481431, -0.00481431], dtype=float32)}

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
x = np.linspace(-1,1)
y = np.linspace(-1,1)
X,Y = np.meshgrid(x,y)
Z = exponential_quartic(np.stack([X,Y],axis=-1))
ax.plot_surface(X,Y,Z,alpha=0.7)

xys = (2*(sobol_seq.i4_sobol_generate(2,20)-0.5)) #[-1,1] cube
zs = exponential_quartic(xys)
ax.scatter(xys[:,0],xys[:,1],zs,color='red')
ax.set_xlabel('x');
ax.set_ylabel('y');

gp = bvbq.gp.SimpleGP(2,kind='smatern32',noise=0)
gp.set_data(xys,zs,empirical_params=True)
gp.optimize_params()
Zreg = gp.predict(np.stack([X,Y],axis=-1))[0]
ax.plot_surface(X,Y,Zreg,alpha=0.7,color='green')
# Out:
# If tensor has more than 2 dimensions, only diagonal of covariance is returned

# %%
x = np.random.rand(5,2)

distrib = bvbq.distributions.DiagonalNormalDistribution(-jnp.ones(2),0.1*jnp.ones(2))
print(distrib.sample(100).mean(axis=0))
print(distrib.logprob(x))
print(distrib.sample(101).mean(axis=0))
# Out:
# [-0.99044454 -1.0060383 ]
# [-301.80716 -158.27931 -294.80444 -237.84756 -310.4032 ]
# [-0.9890031 -1.015915 ]

# %%
distrib.sample(1000)
# Out:
# DeviceArray([[-0.8505697, -1.2835306],
#              [-1.0557429, -0.7975483],
#              [-1.2355732, -0.735934 ],
#              ...,
#              [-1.1745535, -1.3255067],
#              [-0.7992455, -0.7005598],
#              [-1.5006654, -0.9399502]], dtype=float32)

# %%
mixdistrib = distrib.make_mixture()
mixdistrib.add_component(jnp.ones(2),0.1*jnp.ones(2),0.1)
mixdistrib.add_component(2*jnp.ones(2),0.1*jnp.ones(2),0.1)
print(mixdistrib.logprob(x))
print(mixdistrib.sample(100).mean())
print(mixdistrib.sample(101).mean())
# Out:
# [-2.702716  -7.656293  -3.2022219 -6.9514666 -3.0097933]
# -0.37293068
# -0.6136273

# %%
x = mixdistrib.sample(1000)
plt.scatter(x[:,0],x[:,1])

# %%
@jax.jit
def logbound(logx,logdelta):
    clipx = jnp.clip(logx,logdelta,None)
    boundx = clipx + jnp.log(jnp.exp(logx-clipx) + \
                             jnp.exp(logdelta-clipx))
    return boundx

# %%
bvbq.bvi
# Out:
# <module 'bvbq.bvi' from '../bvbq/bvi.py'>

# %%
def logprob_t(x,nu):
    normalizer = jax.scipy.special.gammaln((nu+1)/2) \
                 -jax.scipy.special.gammaln(nu/2) \
                 -0.5*jnp.log(jnp.pi*nu)
    main_term = -(nu+1)/2*jnp.log(1+x**2/nu)
    return main_term + normalizer

def objective_function_relbo_2(params,mixdistrib):
    mean,rawvar = params['mean'],params['rawvar']
    var = jax.nn.softplus(rawvar)
    newcomp = bvbq.distributions.DiagonalNormalDistribution(mean,var)
    logprob = functools.partial(logprob_t,nu=1)
    res = -bvbq.bvi.relbo(logprob,mixdistrib,newcomp,1000,reg=1e0,logdelta=-5)
    return res

def objective_function_gradboost_2(weight,distrib,mixdistrib):
    logprob = functools.partial(logprob_t,nu=1000)
    res = -bvbq.bvi.boosted_elbo(logprob,mixdistrib,distrib,weight,1000)
    return res

params = {'mean':jnp.zeros(1),'rawvar':0.1*jnp.zeros(1)}
distrib = bvbq.distributions.DiagonalNormalDistribution(5*jnp.ones(1),jnp.ones(1))
mixdistrib = distrib.make_mixture()
func_and_grad_relbo = jax.value_and_grad(objective_function_relbo_2,argnums=0)
func_and_grad_relbo(params,mixdistrib)
print(func_and_grad_relbo(params,mixdistrib))
weight = 0.5
func_and_grad_gradboost = jax.value_and_grad(objective_function_gradboost_2)
print(func_and_grad_gradboost(0.5,distrib,mixdistrib))
# Out:
# (DeviceArray(-4.66147, dtype=float32), {'mean': DeviceArray([0.05045595], dtype=float32), 'rawvar': DeviceArray([-0.12207514], dtype=float32)})
# (DeviceArray(12.308316, dtype=float32), DeviceArray(0.00424576, dtype=float32))

# %%
alpha_boost = 1e0
maxiter_boost = 100
alpha_relbo = 3*1e-1
maxiter_relbo = 100
maxiter = 5
optwrapper = bvbq.optwrapper.JaxOptWrapper("adam",alpha_relbo)
for k in range(maxiter):
    params = {'mean':jax.random.normal(mixdistrib.split_key(),(1,)),
              'rawvar':3*jax.random.normal(mixdistrib.split_key(),(1,))}
    optwrapper.init(params,func_and_grad_relbo)
    for i in range(maxiter_relbo):
        value,grads = optwrapper.step(mixdistrib)
        params = optwrapper.params
#         print(value,params['mean'],jax.nn.softplus(params['rawvar']))
    mean,rawvar = params['mean'],params['rawvar']
    var = jax.nn.softplus(rawvar)
    distrib = bvbq.distributions.DiagonalNormalDistribution(mean,var)
    weight = 0.01
    print('--')
    print(mean,var)
    for i in range(maxiter_boost):
        res,gradweight = func_and_grad_gradboost(weight,distrib,mixdistrib)
        weight -= alpha_boost*(i/10+1)**(-0.55)*gradweight
        weight = jnp.clip(weight,1e-4,1-1e-4)
        if abs(gradweight) < 1e-2:
            break
#         print(weight,res,gradweight)
    mixdistrib.add_component(mean,var,weight)
    print(k,mean,var,weight)
    print('--')
# Out:
# --
# [3.8478475] [8.775109]
# 0 [3.8478475] [8.775109] 1e-04
# --
# --
# [2.8661525] [15.713153]
# 1 [2.8661525] [15.713153] 1e-04
# --
# --
# [2.5462508] [18.28128]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b42ef7460cbb> in <module>
#      20     print(mean,var)
#      21     for i in range(maxiter_boost):
# ---> 22         res,gradweight = func_and_grad_gradboost(weight,distrib,mixdistrib)
#      23         weight -= alpha_boost*(i/10+1)**(-0.55)*gradweight
#      24         weight = jnp.clip(weight,1e-4,1-1e-4)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     807     tree_map(partial(_check_input_dtype_grad, holomorphic, allow_int), dyn_args)
#     808     if not has_aux:
# --> 809       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     810     else:
#     811       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/api.py in _vjp(fun, has_aux, *primals)
#    1876   if not has_aux:
#    1877     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1878     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1879     out_tree = out_tree()
#    1880   else:
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     112 def vjp(traceable, primals, has_aux=False):
#     113   if not has_aux:
# --> 114     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     115   else:
#     116     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      99   _, in_tree = tree_flatten(((primals, primals), {}))
#     100   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 101   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     102   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     103   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     496   with core.new_main(JaxprTrace) as main:
#     497     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 498     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     499     assert not env
#     500     del main, fun, env
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# <ipython-input-23-8407823aabf2> in objective_function_gradboost_2(weight, distrib, mixdistrib)
#      16 def objective_function_gradboost_2(weight,distrib,mixdistrib):
#      17     logprob = functools.partial(logprob_t,nu=1000)
# ---> 18     res = -bvbq.bvi.boosted_elbo(logprob,mixdistrib,distrib,weight,1000)
#      19     return res
#      20
#
# ~/Danilo/NIDF/Inference/bvbq/bvbq/bvi.py in boosted_elbo(logprob, distrib, newcomp, newweight, nsamples)
#      13     joint_distrib = distrib.add_component(*newcomp.params,newweight,return_new=True)
#      14     logprob_mean_1 = logprob(samples_distrib).mean()
# ---> 15     partial_entropy_1 = -joint_distrib.logprob(samples_distrib).mean()
#      16     logprob_mean_2 = logprob(samples_newcomp).mean()
#      17     partial_entropy_2 = -joint_distrib.logprob(samples_newcomp).mean()
#
# ~/Danilo/NIDF/Inference/bvbq/bvbq/distributions.py in logprob(self, x)
#      96
#      97     def logprob(self,x):
# ---> 98         res = self._logprob(x,self.means,self.stds,self.weights)
#      99         return res
#     100
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/api.py in cache_miss(*args, **kwargs)
#     336         backend=backend,
#     337         name=flat_fun.__name__,
# --> 338         donated_invars=donated_invars)
#     339     out_pytree_def = out_tree()
#     340     out = tree_unflatten(out_pytree_def, out_flat)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     306     update_params = call_param_updaters.get(call_primitive)
#     307     new_params = update_params(params, nz_tangents) if update_params else params
# --> 308     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     309     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     310     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     190     with ctx:
#     191       jaxpr, out_pvals, consts, env_tracers = self.partial_eval(
# --> 192           f, in_pvals, app, instantiate=False)
#     193       if primitive.map_primitive:
#     194         unmapped_aval = partial(core.unmapped_aval, params['axis_size'])
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in partial_eval(self, f, pvals, app, instantiate)
#     297     f = trace_to_subjaxpr(f, self.main, instantiate)
#     298     f, aux = partial_eval_wrapper(f, tuple(in_avals))
# --> 299     out_flat, (out_avals, jaxpr, env) = app(f, *in_consts), aux()
#     300     out_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#     301     out_pvs = map(PartialVal, zip(out_avals, out_consts))
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     598
#     599   def process_call(self, primitive, f, tracers, params):
# --> 600     return primitive.impl(f, *tracers, **params)
#     601   process_map = process_call
#     602
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     575 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
#     576   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
# --> 577                                *unsafe_map(arg_spec, args))
#     578   try:
#     579     return compiled_fun(*args)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     258       fun.populate_stores(stores)
#     259     else:
# --> 260       ans = call(fun, *args)
#     261       cache[key] = (ans, fun.stores)
#     262
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     714       device_assignment=(device.id,) if device else None)
#     715   options.parameter_is_tupled_arguments = tuple_args
# --> 716   compiled = backend_compile(backend, built, options)
#     717   if nreps == 1:
#     718     return partial(_execute_compiled, compiled, out_avals, result_handlers)
#
# ~/anaconda3/envs/danilo_env_1/lib/python3.7/site-packages/jax/interpreters/xla.py in backend_compile(backend, built_c, options)
#     341   # we use a separate function call to ensure that XLA compilation appears
#     342   # separately in Python profiling results
# --> 343   return backend.compile(built_c, compile_options=options)
#     344
#     345 def _execute_compiled_primitive(prim, compiled, result_handler, *args):
#
# KeyboardInterrupt:

# %%
x = np.linspace(-10,10,201)
y = logprob_t(x,1000)
y2 = -0.5*x**2 - 0.5*np.log(2*np.pi)
yvi = mixdistrib.logprob(x.reshape(-1,1)).flatten()
plt.plot(x,np.exp(y),'b')
plt.plot(x,np.exp(y2),'r')
plt.plot(x,np.exp(yvi),'g')

# %%
mixdistrib.weights.sum()
# Out:
# DeviceArray(0.99999994, dtype=float32)

# %%
mixdistrib.add_component(np.zeros(1),np.ones(1),0.5)

# %%
def exponential_quartic(x):
    x1,x2 = x[...,0],x[...,1]
    res = -0.1*x1**4 -0.5*(2*x2-x1**2)**2
#     return -0.5*((x1+1)**2 + (x2 - 1)**2)
    return res

def objective_function_relbo_2(params,mixdistrib):
    mean,rawvar = params['mean'],params['rawvar']
    var = jax.nn.softplus(rawvar)
    newcomp = bvbq.distributions.DiagonalNormalDistribution(mean,var)
    logprob = functools.partial(logprob_t,nu=1)
    res = -bvbq.bvi.relbo(logprob,mixdistrib,newcomp,1000,reg=1e0,logdelta=-5)
    return res

def objective_function_gradboost_2(weight,distrib,mixdistrib):
#     logprob = functools.partial(logprob_t,nu=1000)
    logprob = exponential_quartic
    res = -bvbq.bvi.boosted_elbo(logprob,mixdistrib,distrib,weight,1000)
    return res

params = {'mean':jnp.zeros(2),'rawvar':0.1*jnp.zeros(2)}
distrib = bvbq.distributions.DiagonalNormalDistribution(jnp.zeros(2),jnp.ones(2))
mixdistrib = distrib.make_mixture()
func_and_grad_relbo = jax.value_and_grad(objective_function_relbo_2,argnums=0)
func_and_grad_relbo(params,mixdistrib)
print(func_and_grad_relbo(params,mixdistrib))
weight = 0.5
func_and_grad_gradboost = jax.value_and_grad(objective_function_gradboost_2)
print(func_and_grad_gradboost(0.5,distrib,mixdistrib))
# Out:
# (DeviceArray(-3.3161716, dtype=float32), {'mean': DeviceArray([-0.0060608 , -0.00559549], dtype=float32), 'rawvar': DeviceArray([-0.45201987, -0.45770144], dtype=float32)})
# (DeviceArray(0.835276, dtype=float32), DeviceArray(-0.02615952, dtype=float32))

# %%
alpha_boost = 1e0
maxiter_boost = 100
alpha_relbo = 1e-3
maxiter_relbo = 100
maxiter = 10
optwrapper = bvbq.optwrapper.JaxOptWrapper("adam",alpha_relbo)
for k in range(maxiter):
    params = {'mean':jax.random.normal(mixdistrib.split_key(),(2,)),
              'rawvar':3*jax.random.normal(mixdistrib.split_key(),(2,))}
    optwrapper.init(params,func_and_grad_relbo)
    for i in range(maxiter_relbo):
        value,grads = optwrapper.step(mixdistrib)
        params = optwrapper.params
#         print(value,params['mean'],jax.nn.softplus(params['rawvar']))
    mean,rawvar = params['mean'],params['rawvar']
    var = jax.nn.softplus(rawvar)
#     mean,var = jnp.zeros(1),jnp.ones(1)
    distrib = bvbq.distributions.DiagonalNormalDistribution(mean,var)
    weight = 1e-12
    print('--')
    print(mean,var)
    for i in range(maxiter_boost):
        res,gradweight = func_and_grad_gradboost(weight,distrib,mixdistrib)
        weight -= alpha_boost*(i/10+1)**(-0.55)*gradweight
        weight = jnp.clip(weight,1e-12,1-1e12)
        if abs(gradweight) < 1e-2:
            break
        print(weight,res,gradweight)
    mixdistrib.add_component(mean,var,weight)
    print(k,mean,var,weight)
    print('--')
# Out:
# --
# [ 1.0887313  -0.76624817] [0.00164976 0.3564104 ]
# -1000000000000.0 1.0079429 0.77146375
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 0 [ 1.0887313  -0.76624817] [0.00164976 0.3564104 ] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 1 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 2 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 3 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 4 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 5 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 6 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 7 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 8 [nan nan] [nan nan] nan
# --
# --
# [nan nan] [nan nan]
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# nan nan nan
# 9 [nan nan] [nan nan] nan
# --
