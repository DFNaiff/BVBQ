# %%
# %load_ext autoreload
# %autoreload 2

# %%
import functools

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import sobol_seq

import bvbq

# %%
dim = 2
def exponential_quartic(x):
    x1,x2 = x[...,0],x[...,1]
    res = -0.1*x1**4 -0.5*(2*x2-x1**2)**2
#     return -0.5*((x1+1)**2 + (x2 - 1)**2)
    return res

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
x = np.linspace(-1,1)
y = np.linspace(-1,1)
X,Y = np.meshgrid(x,y)
Z = exponential_quartic(np.stack([X,Y],axis=-1))
ax.plot_surface(X,Y,Z,alpha=0.7)

# %%
inferencer = bvbq.BVBQMixMVN(['x1', 'x1'], [1, 1], [(None, None), (None, None)])

# %%
xdata = (2*(sobol_seq.i4_sobol_generate(2,20)-0.5)) #[-1,1] cube
ydata = exponential_quartic(xdata)
params_init = {'x':xdata}
inferencer.initialize_data(params_init,params_evals,empirical_params=True)
inferencer.initialize_components(mean=torch.zeros(2),var=20*torch.ones(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31549/2582641097.py in <module>
# ----> 1 inferencer.initialize_data(params_init,params_evals,empirical_params=True)
#       2 inferencer.initialize_components(mean=torch.zeros(2),var=20*torch.ones(2))
#
# NameError: name 'params_init' is not defined

# %%
xdata
# Out:
# array([[ 0.    ,  0.    ],
#        [ 0.5   , -0.5   ],
#        [-0.5   ,  0.5   ],
#        [-0.25  , -0.25  ],
#        [ 0.75  ,  0.75  ],
#        [ 0.25  , -0.75  ],
#        [-0.75  ,  0.25  ],
#        [-0.625 , -0.375 ],
#        [ 0.375 ,  0.625 ],
#        [ 0.875 , -0.875 ],
#        [-0.125 ,  0.125 ],
#        [-0.375 , -0.625 ],
#        [ 0.625 ,  0.375 ],
#        [ 0.125 , -0.125 ],
#        [-0.875 ,  0.875 ],
#        [-0.8125, -0.0625],
#        [ 0.1875,  0.9375],
#        [ 0.6875, -0.5625],
#        [-0.3125,  0.4375],
#        [-0.0625, -0.8125]])
